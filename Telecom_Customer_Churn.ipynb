# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/1730285168-TelecomCustomerChurn.csv")
df.head(3)
# Out:
#    customerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 0          No          No              No   Monthly              Yes
# 1          No          No              No  One year               No
# 2          No          No              No   Monthly              Yes
#
#   PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   Tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_x = df.iloc[:,1:]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       Tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['customerID', 'Gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'Tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
y = df['Churn']
X = df.drop(['customerID','Churn'],axis=1)

# %%
y.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler()

# %%
X, y = ros.fit_resample(X,y)

# %%
X.head()
# Out:
#    Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 3            No             DSL            Yes           No              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# ...

# %%
y
# Out:
# 0         No
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 10343    Yes
# 10344    Yes
# 10345    Yes
# 10346    Yes
# 10347    Yes
# Name: Churn, Length: 10348, dtype: object

# %%
y.value_counts()
# Out:
# Churn
# No     5174
# Yes    5174
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd
import numpy as np
from imblearn.over_sampling import RandomOverSampler # Ensure RandomOverSampler is imported here

# Re-establish X and y from the original dataframe, then apply oversampling
# This makes this cell robust to being re-run, as X will always be a DataFrame after this point
# before the encoding process.
# 'df' is available from JS8ByN9ge1Js
# 'ros' is initialized in wyJouxV-G1ZK (but re-initialized here for robustness)
# 'categorical_cols_for_oe' and 'final_model_feature_order' are from 5ca65fc0

# Step 1: Re-create the initial X and y from the original df
X_initial_df = df.drop(['customerID','Churn'],axis=1)
y_initial = df['Churn']

# Step 2: Apply oversampling to X_initial_df
ros = RandomOverSampler() # Re-initialize ros locally for robustness
X_oversampled_df, y_oversampled = ros.fit_resample(X_initial_df, y_initial)

# Initialize OrdinalEncoder with handle_unknown to prevent errors for unseen categories
oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

# X_oversampled_df is now guaranteed to be a DataFrame
# Apply OrdinalEncoder to categorical columns of this DataFrame
X_processed_for_model_df = X_oversampled_df.copy() # Make a copy to avoid modifying X_oversampled_df in place
X_processed_for_model_df[categorical_cols_for_oe] = oe.fit_transform(X_processed_for_model_df[categorical_cols_for_oe])

# Convert the processed DataFrame to a NumPy array of float type
# This will be the global 'X' used for train_test_split and model training
X = X_processed_for_model_df[final_model_feature_order].values.astype(float)
# Update the global 'y' to its oversampled version, consistent with X
y = y_oversampled

# %%
X
# Out:
# array([[0.000e+00, 0.000e+00, 1.000e+00, ..., 2.000e+00, 1.420e+02,
#         2.505e+03],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 2.000e+00, 4.980e+02,
#         1.466e+03],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 2.000e+00, 4.360e+02,
#         1.570e+02],
#        ...,
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 1.000e+00, 1.321e+03,
#         1.320e+02],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 0.000e+00, 2.500e+01,
#         1.932e+03],
#        [1.000e+00, 1.000e+00, 1.000e+00, ..., 2.000e+00, 3.020e+02,
#         2.230e+03]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=2529)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.94      0.81      0.87      1290
#          Yes       0.83      0.95      0.89      1297
#
#     accuracy                           0.88      2587
#    macro avg       0.89      0.88      0.88      2587
# weighted avg       0.89      0.88      0.88      2587
